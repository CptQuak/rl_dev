# %%
# %reload_ext autoreload
# %autoreload 2
from env import DynaMaze, Agent

# %%
env = DynaMaze()
agent1 = Agent(n_planning=0)
agent1.dynaq(env, n_episodes=50)
agent2 = Agent(n_planning=5)
agent2.dynaq(env, n_episodes=50)
agent3 = Agent(n_planning=50)
agent3.dynaq(env, n_episodes=50)

# %%
import matplotlib.pyplot as plt

plt.plot(agent1.episode_lengths)
plt.plot(agent2.episode_lengths)
plt.plot(agent3.episode_lengths)
plt.legend(["0 planning", "5 planning", "50 planning"])
plt.grid()
